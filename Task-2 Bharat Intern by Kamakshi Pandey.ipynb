# %% [markdown]
# # APPLE STOCK PRICE PREDICTION

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#reading dataset
df = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\AAPL.csv")

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1    2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2    2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3    2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4    2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
# 248  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 249  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 250  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 251  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
#
#        Volume
# 0    64823400
# 1    65086600
# 2    66675400
# 3    53623900
# 4    55138700
# ..        ...
# 247  41573900
# 248  50520200
# 249  48353800
# 250  80507300
# 251  59415700
#
# [252 rows x 7 columns]

# %%
df.shape
# Out:
# (252, 7)

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    object
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   157.455874  159.283214  155.896548  157.698849  157.313404
# std     16.419670   16.239506   16.760355   16.543517   16.671563
# min    126.010002  127.769997  124.169998  125.019997  124.656982
# 25%    145.817505  147.360005  144.072502  145.924996  145.488319
# 50%    153.945000  156.345002  152.479996  154.489998  153.801232
# 75%    169.334999  170.192501  167.255001  168.502502  168.209835
# max    195.089996  198.229996  192.649994  195.100006  195.100006
#
#              Volume
# count  2.520000e+02
# mean   7.104434e+07
# std    2.293748e+07
# min    3.145820e+07
# 25%    5.424295e+07
# 50%    6.714875e+07
# 75%    8.140258e+07
# max    1.647624e+08

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.Close.hist();

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1  2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2  2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3  2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4  2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
#
#      Volume
# 0  64823400
# 1  65086600
# 2  66675400
# 3  53623900
# 4  55138700

# %%
df.Date.dtype
# Out:
# dtype('O')

# %%
df.Date.head()
# Out:
# 0    2022-07-20
# 1    2022-07-21
# 2    2022-07-22
# 3    2022-07-25
# 4    2022-07-26
# Name: Date, dtype: object

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1  2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2  2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3  2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4  2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
#
#      Volume
# 0  64823400
# 1  65086600
# 2  66675400
# 3  53623900
# 4  55138700

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 247  2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
# 248  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 249  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 250  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 251  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
#
#        Volume
# 247  41573900
# 248  50520200
# 249  48353800
# 250  80507300
# 251  59415700

# %%
df.sort_values(by=["Date"], inplace=True, ascending=True)
df.Date.head()
# Out:
# 0    2022-07-20
# 1    2022-07-21
# 2    2022-07-22
# 3    2022-07-25
# 4    2022-07-26
# Name: Date, dtype: object

# %%
fig, ax = plt.subplots()
ax.scatter(df.Date, df.Close);

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1    2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2    2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3    2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4    2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
# 248  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 249  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 250  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 251  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
#
#        Volume
# 0    64823400
# 1    65086600
# 2    66675400
# 3    53623900
# 4    55138700
# ..        ...
# 247  41573900
# 248  50520200
# 249  48353800
# 250  80507300
# 251  59415700
#
# [252 rows x 7 columns]

# %%
copy_df = df.copy()
copy_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1    2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2    2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3    2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4    2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
# 248  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 249  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 250  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 251  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
#
#        Volume
# 0    64823400
# 1    65086600
# 2    66675400
# 3    53623900
# 4    55138700
# ..        ...
# 247  41573900
# 248  50520200
# 249  48353800
# 250  80507300
# 251  59415700
#
# [252 rows x 7 columns]

# %%
copy_df.reset_index(inplace =True)
copy_df
# Out:
#      index        Date        Open        High         Low       Close  \
# 0        0  2022-07-20  151.119995  153.720001  150.369995  153.039993
# 1        1  2022-07-21  154.500000  155.570007  151.940002  155.350006
# 2        2  2022-07-22  155.389999  156.279999  153.410004  154.089996
# 3        3  2022-07-25  154.009995  155.039993  152.279999  152.949997
# 4        4  2022-07-26  152.259995  153.089996  150.800003  151.600006
# ..     ...         ...         ...         ...         ...         ...
# 247    247  2023-07-14  190.229996  191.179993  189.630005  190.690002
# 248    248  2023-07-17  191.899994  194.320007  191.809998  193.990005
# 249    249  2023-07-18  193.350006  194.330002  192.419998  193.729996
# 250    250  2023-07-19  193.100006  198.229996  192.649994  195.100006
# 251    251  2023-07-20  195.089996  196.470001  192.500000  193.130005
#
#       Adj Close    Volume
# 0    152.131577  64823400
# 1    154.427872  65086600
# 2    153.175354  66675400
# 3    152.042114  53623900
# 4    150.700134  55138700
# ..          ...       ...
# 247  190.690002  41573900
# 248  193.990005  50520200
# 249  193.729996  48353800
# 250  195.100006  80507300
# 251  193.130005  59415700
#
# [252 rows x 8 columns]

# %%
copy_df.drop("index", axis=1, inplace=True)
copy_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1    2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2    2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3    2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4    2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
# 248  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 249  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 250  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 251  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
#
#        Volume
# 0    64823400
# 1    65086600
# 2    66675400
# 3    53623900
# 4    55138700
# ..        ...
# 247  41573900
# 248  50520200
# 249  48353800
# 250  80507300
# 251  59415700
#
# [252 rows x 7 columns]

# %%
copy_df.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5180\2690332376.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   copy_df.corr()
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.995726  0.996498  0.990336   0.990305 -0.412307
# High       0.995726  1.000000  0.996333  0.996248   0.996045 -0.380812
# Low        0.996498  0.996333  1.000000  0.996271   0.996317 -0.434163
# Close      0.990336  0.996248  0.996271  1.000000   0.999892 -0.404481
# Adj Close  0.990305  0.996045  0.996317  0.999892   1.000000 -0.408060
# Volume    -0.412307 -0.380812 -0.434163 -0.404481  -0.408060  1.000000

# %%
plt.figure(figsize=(10,7))
plt.plot(copy_df["Date"],
         copy_df["Close"])
plt.xlabel("Date")
plt.ylabel("Closed Price");
plt.title("Variation of Closing price with different Date year",
          color="orange",
          fontsize=18);

# %%
close_df = copy_df["Close"]
close_df
# Out:
# 0      153.039993
# 1      155.350006
# 2      154.089996
# 3      152.949997
# 4      151.600006
#           ...
# 247    190.690002
# 248    193.990005
# 249    193.729996
# 250    195.100006
# 251    193.130005
# Name: Close, Length: 252, dtype: float64

# %%
close_df.size
# Out:
# 252

# %%
close_df.shape
# Out:
# (252,)

# %%
close_df.info
# Out:
# <bound method Series.info of 0      153.039993
# 1      155.350006
# 2      154.089996
# 3      152.949997
# 4      151.600006
#           ...
# 247    190.690002
# 248    193.990005
# 249    193.729996
# 250    195.100006
# 251    193.130005
# Name: Close, Length: 252, dtype: float64>

# %%
close_df.describe
# Out:
# <bound method NDFrame.describe of 0      153.039993
# 1      155.350006
# 2      154.089996
# 3      152.949997
# 4      151.600006
#           ...
# 247    190.690002
# 248    193.990005
# 249    193.729996
# 250    195.100006
# 251    193.130005
# Name: Close, Length: 252, dtype: float64>

# %%
plt.plot(copy_df.Date, close_df)
plt.xlabel("Time in Year")
plt.ylabel("Closing Price");
plt.title("Variation of Closing price with Time",
          color="orange",
          fontsize=18);

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxSca
#        [7.92665566e-01],
#        [7.98230634e-01],
#        [8.38612849e-01],
#        [8.31763606e-01],
#        [8.40896011e-01],
#        [8.70290956e-01],
#        [8.54737347e-01],
#        [8.56021551e-01],
#        [8.41038847e-01],
#        [8.84417737e-01],
#        [8.79851428e-01],
#        [8.59731725e-01],
#        [8.99543278e-01],
#        [9.16523898e-01],
#        [9.21375438e-01],
#        [9.83875502e-01],
#        [9.62328786e-01],
#        [9.46204288e-01],
#        [9.53053545e-01],
#        [9.36929046e-01],
#        [9.07391493e-01],
#        [8.99828723e-01],
#        [9.23944045e-01],
#        [9.34931330e-01],
#        [9.37071869e-01],
#        [9.84160947e-01],
#        [9.80450773e-01],
#        [1.00000000e+00],
#        [9.71889259e-01]])

# %%
train_size = int(len(close_df)*0.7)
test_size = len(close_df) - train_size
train_data = close_df[:train_size, :] # Slicing row from 0 to train_size indexlocation but column is kept unsliced.
test_data = close_df[train_size:len(close_df), :1]

# %%
train_data.shape
# Out:
# (176, 1)

# %%
test_data.shape
# Out:
# (76, 1)

# %%
176+76
# Out:
# 252

# %%
test_data[:10]
# Out:
# array([[0.56906381],
#        [0.58718601],
#        [0.57948063],
#        [0.5527967 ],
#        [0.5656393 ],
#        [0.52811069],
#        [0.51055938],
#        [0.50057084],
#        [0.57848168],
#        [0.57348751]])

# %%
#This function will create dataset as mentioned above...

def create_dataset(dataset, time_step):
    X_data = []
    Y_data = []
    for i in range(len(dataset)-time_step-1):
        X_data.append(dataset[i:(i+time_step), 0])
        Y_data.append(dataset[i+time_step, 0])
    return np.array(X_data), np.array(Y_data)

# %%
# Reshaping into tuples of the form with X=t, t+1,..t+99 and Y=t+100 for time_step=100

time_step = 50
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train.shape
# Out:
# (125, 50)

# %%
y_train.shape
# Out:
# (125,)

# %%
X_test.shape, y_test.shape
# Out:
# ((25, 50), (25,))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()

# %%
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
#Adding third LSTM layer and some dropouts

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
#Adding fourth LSTM layer and some dropouts

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
#Adding the output layer

regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to Training Data Set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 38s 195ms/step - loss: 0.0522
# Epoch 2/100
# 4/4 [==============================] - 1s 121ms/step - loss: 0.0263
# Epoch 3/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0206
# Epoch 4/100
# 4/4 [==============================] - 1s 127ms/step - loss: 0.0180
# Epoch 5/100
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0147
# Epoch 6/100
# 4/4 [==============================] - 1s 126ms/step - loss: 0.0150
# Epoch 7/100
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0139
# Epoch 8/100
# 4/4 [==============================] - 1s 122ms/step - loss: 0.0154
# Epoch 9/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0127
# Epoch 10/100
# 4/4 [==============================] - 1s 127ms/step - loss: 0.0129
# Epoch 11/100
# 4/4 [==============================] - 0s 120ms/step - loss: 0.0125
# Epoch 12/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0119
# Epoch 13/100
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0126
# Epoch 14/100
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0127
# Epoch 15/100
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0121
# Epoch 16/100
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0115
# Epoch 17/100
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0113
# Epoch 18/100
# 4/4 [==============================] - 1s 124ms/step - loss: 0.0104
# Epoch 19/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0106
# Epoch 20/100
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0096
# Epoch 21/100
# 4/4 [==============================] - 1s 128ms/step - loss: 0.0102
# Epoch 22/100
# 4/4 [==============================] - 1s 126ms/step - loss: 0.0102
# Epoch 23/100
# 4/4 [==============================] - 1s 127ms/step - loss: 0.0102
# Epoch 24/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0087
# Epoch 25/100
# 4/4 [==============================] - 1s 128ms/step - loss: 0.0090
# Epoch 26/100
# 4/4 [==============================] - 0s 127ms/step - loss: 0.0089
# Epoch 27/100
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0095
# Epoch 28/100
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0084
# Epoch 29/100
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0085
# Epoch 30/100
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0087
# Epoch 31/100
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0085
# Epoch 32/100
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0081
# Epoch 33/100
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0084
# Epoch 34/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.0088
# Epoch 35/100
# 4/4 [==============================] - 0s 119ms/step - loss: 0.0078
# Epoch 36/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0078
# Epoch 37/100
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0087
# Epoch 38/100
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0078
# Epoch 39/100
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0079
# Epoch 40/100
# 4/4 [==============================] - 1s 125ms/step - loss: 0.0079
# Epoch 41/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0075
# Epoch 42/100
# 4/4 [==============================] - 0s 95ms/step - loss: 0.0073
# Epoch 43/100
# 4/4 [==============================] - 1s 205ms/step - loss: 0.0075
# Epoch 44/100
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0076
# Epoch 45/100
# 4/4 [==============================] - 1s 171ms/step - loss: 0.0073
# Epoch 46/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.0083
# Epoch 47/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.0076
# Epoch 48/100
# 4/4 [==============================] - 1s 151ms/step - loss: 0.0071
# Epoch 49/100
# 4/4 [==============================] - 1s 155ms/step - loss: 0.0073
# Epoch 50/100
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0074
# Epoch 51/100
# 4/4 [==============================] - 1s 182ms/step - loss: 0.0069
# Epoch 52/100
# 4/4 [==============================] - 1s 183ms/step - loss: 0.0066
# Epoch 53/100
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0082
# Epoch 54/100
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0069
# Epoch 55/100
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0077
# Epoch 56/100
# 4/4 [==============================] - 1s 183ms/step - loss: 0.0070
# Epoch 57/100
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0076
# Epoch 58/100
# 4/4 [==============================] - 1s 150ms/step - loss: 0.0069
# Epoch 59/100
# 4/4 [==============================] - 1s 153ms/step - loss: 0.0068
# Epoch 60/100
# 4/4 [==============================] - 1s 145ms/step - loss: 0.0063
# Epoch 61/100
# 4/4 [==============================] - 1s 145ms/step - loss: 0.0065
# Epoch 62/100
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0061
# Epoch 63/100
# 4/4 [==============================] - 1s 166ms/step - loss: 0.0070
# Epoch 64/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.0067
# Epoch 65/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.0066
# Epoch 66/100
# 4/4 [==============================] - 1s 147ms/step - loss: 0.0063
# Epoch 67/100
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0074
# Epoch 68/100
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0063
# Epoch 69/100
# 4/4 [==============================] - 1s 154ms/step - loss: 0.0062
# Epoch 70/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0062
# Epoch 71/100
# 4/4 [==============================] - 1s 168ms/step - loss: 0.0059
# Epoch 72/100
# 4/4 [==============================] - 1s 177ms/step - loss: 0.0070
# Epoch 73/100
# 4/4 [==============================] - 1s 154ms/step - loss: 0.0070
# Epoch 74/100
# 4/4 [==============================] - 1s 155ms/step - loss: 0.0067
# Epoch 75/100
# 4/4 [==============================] - 1s 153ms/step - loss: 0.0061
# Epoch 76/100
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0054
# Epoch 77/100
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0060
# Epoch 78/100
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0060
# Epoch 79/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.0065
# Epoch 80/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0063
# Epoch 81/100
# 4/4 [==============================] - 1s 154ms/step - loss: 0.0056
# Epoch 82/100
# 4/4 [==============================] - 1s 147ms/step - loss: 0.0064
# Epoch 83/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.0061
# Epoch 84/100
# 4/4 [==============================] - 1s 152ms/step - loss: 0.0063
# Epoch 85/100
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0053
# Epoch 86/100
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0051
# Epoch 87/100
# 4/4 [==============================] - 1s 165ms/step - loss: 0.0054
# Epoch 88/100
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0057
# Epoch 89/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.0055
# Epoch 90/100
# 4/4 [==============================] - 1s 150ms/step - loss: 0.0057
# Epoch 91/100
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0055
# Epoch 92/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0056

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# Constructing our stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1))) #Input layer with 50 neurons
model.add(LSTM(50, return_sequences=True)) # Hidden layers with 50 neurons
model.add(LSTM(50))
model.add(Dense(1))# Output Layer
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()

# %%
dataset_test = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\AAPL.csv")
df
real_stock_price = dataset_test.iloc[:, 1:2].values

dataset_test
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1    2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2    2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3    2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4    2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
# 248  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 249  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 250  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 251  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
#
#        Volume
# 0    64823400
# 1    65086600
# 2    66675400
# 3    53623900
# 4    55138700
# ..        ...
# 247  41573900
# 248  50520200
# 249  48353800
# 250  80507300
# 251  59415700
#
# [252 rows x 7 columns]

# %%
real_stock_price
# Out:
# array([[151.119995],
#        [154.5     ],
#        [155.389999],
#        [154.009995],
#        [152.259995],
#        [152.580002],
#        [156.979996],
#        [161.240005],
#        [161.009995],
#        [160.100006],
#        [160.839996],
#        [166.009995],
#        [163.210007],
#        [166.369995],
#        [164.020004],
#        [167.679993],
#        [170.059998],
#        [169.820007],
#        [171.520004],
#        [172.779999],
#        [172.770004],
#        [173.75    ],
#        [173.029999],
#        [169.690002],
#        [167.080002],
#        [167.320007],
#        [168.779999],
#        [170.570007],
#        [161.149994],
#        [162.130005],
#        [160.309998],
#        [156.639999],
#        [159.75    ],
#        [156.470001],
#        [154.820007],
#        [154.639999],
#        [155.470001],
#        [159.589996],
#        [159.899994],
#        [154.789993],
#        [154.649994],
#        [151.210007],
#        [149.309998],
#        [153.399994],
#        [157.339996],
#        [152.380005],
#        [151.190002],
#        [149.660004],
#        [152.740005],
#        [147.639999],
#        [146.100006],
#        [141.279999],
#        [138.210007],
#        [145.029999],
#        [144.070007],
#        [145.809998],
#        [142.539993],
#        [140.419998],
#        [139.899994],
#        [139.130005],
#        [134.990005],
#        [144.309998],
#        [141.070007],
#        [145.490005],
#        [141.690002],
#        [143.020004],
#        [142.869995],
#        [147.190002],
#        [150.089996],
#        [150.960007],
#        [148.070007],
#        [148.199997],
#        [153.160004],
#        [155.080002],
#        [148.949997],
#        [142.059998],
#        [142.089996],
#        [137.110001],
#        [140.410004],
#        [138.5     ],
#        [141.240005],
#        [145.820007],
#        [148.970001],
#        [152.220001],
#        [149.130005],
#        [146.429993],
#        [152.309998],
#        [150.160004],
#        [148.130005],
#        [149.449997],
#        [148.309998],
#        [145.139999],
#        [144.289993],
#        [141.399994],
#        [148.210007],
#        [145.960007],
#        [147.770004],
#        [147.070007],
#        [142.190002],
#        [142.360001],
#        [142.339996],
#        [142.699997],
#        [149.5     ],
#        [145.350006],
#        [141.110001],
#        [136.690002],
#        [135.110001],
#        [131.389999],
#        [132.979996],
#        [134.350006],
#        [130.919998],
#        [131.380005],
#        [129.669998],
#        [127.989998],
#        [128.410004],
#        [130.279999],
#        [126.889999],
#        [127.129997],
#        [126.010002],
#        [130.470001],
#        [130.259995],
#        [131.25    ],
#        [133.880005],
#        [132.029999],
#        [134.830002],
#        [136.820007],
#        [134.080002],
#        [135.279999],
#        [138.119995],
#        [140.309998],
#        [140.889999],
#        [143.169998],
#        [143.160004],
#        [144.960007],
#        [142.699997],
#        [143.970001],
#        [148.899994],
#        [148.029999],
#        [152.570007],
#        [150.639999],
#        [153.880005],
#        [153.779999],
#        [149.460007],
#        [150.949997],
#        [152.119995],
#        [153.110001],
#        [153.509995],
#        [152.350006],
#        [150.199997],
#        [148.869995],
#        [150.089996],
#        [147.110001],
#        [147.710007],
#        [147.050003],
#        [146.830002],
#        [144.380005],
#        [148.039993],
#        [153.789993],
#        [153.699997],
#        [152.809998],
#        [153.559998],
#        [150.210007],
#        [147.809998],
#        [151.279999],
#        [151.190002],
#        [152.160004],
#        [156.080002],
#        [155.070007],
#        [157.320007],
#        [159.300003],
#        [158.830002],
#        [158.860001],
#        [159.940002],
#        [157.970001],
#        [159.369995],
#        [161.529999],
#        [162.440002],
#        [164.270004],
#        [166.600006],
#        [164.740005],
#        [162.429993],
#        [161.419998],
#        [162.350006],
#        [161.220001],
#        [161.630005],
#        [164.589996],
#        [165.089996],
#        [166.100006],
#        [165.800003],
#        [166.089996],
#        [165.050003],
#        [165.      ],
#        [165.190002],
#        [163.059998],
#        [165.190002],
#        [168.490005],
#        [169.279999],
#        [170.089996],
#        [169.5     ],
#        [164.889999],
#        [170.979996],
#        [172.479996],
#        [173.050003],
#        [173.020004],
#        [173.850006],
#        [173.619995],
#        [173.160004],
#        [171.990005],
#        [171.710007],
#        [173.      ],
#        [176.389999],
#        [173.979996],
#        [173.130005],
#        [171.089996],
#        [172.410004],
#        [173.320007],
#        [176.960007],
#        [177.330002],
#        [177.699997],
#        [181.029999],
#        [182.630005],
#        [179.970001],
#        [178.440002],
#        [177.899994],
#        [181.5     ],
#        [181.270004],
#        [182.800003],
#        [183.369995],
#        [183.960007],
#        [186.729996],
#        [184.410004],
#        [184.899994],
#        [183.740005],
#        [185.550003],
#        [186.830002],
#        [185.889999],
#        [187.929993],
#        [189.080002],
#        [191.630005],
#        [193.779999],
#        [191.570007],
#        [189.839996],
#        [191.410004],
#        [189.259995],
#        [189.160004],
#        [189.679993],
#        [190.5     ],
#        [190.229996],
#        [191.899994],
#        [193.350006],
#        [193.100006],
#        [195.089996]])

# %%
dataset_train =pd.read_csv("C:\\Users\\Lenovo\\Downloads\\AAPL.csv")
predicted_stock_price = dataset_train.iloc[:, 1:2].values

dataset_train
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-07-20  151.119995  153.720001  150.369995  153.039993  152.131577
# 1    2022-07-21  154.500000  155.570007  151.940002  155.350006  154.427872
# 2    2022-07-22  155.389999  156.279999  153.410004  154.089996  153.175354
# 3    2022-07-25  154.009995  155.039993  152.279999  152.949997  152.042114
# 4    2022-07-26  152.259995  153.089996  150.800003  151.600006  150.700134
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
# 248  2023-07-17  191.899994  194.320007  191.809998  193.990005  193.990005
# 249  2023-07-18  193.350006  194.330002  192.419998  193.729996  193.729996
# 250  2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 251  2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
#
#        Volume
# 0    64823400
# 1    65086600
# 2    66675400
# 3    53623900
# 4    55138700
# ..        ...
# 247  41573900
# 248  50520200
# 249  48353800
# 250  80507300
# 251  59415700
#
# [252 rows x 7 columns]

# %%
X_test = []
for i in range(60, 250):
    X_test.append(close_df[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
plt.plot(real_stock_price, color = 'orange', label = 'Real AAPL Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted AAPL Stock Price')
plt.title('AAPL Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('AAPL Stock Price')
plt.legend()
plt.show()

# %%
train_preds = minmax.inverse_transform(model.predict(X_train))
test_preds = minmax.inverse_transform(model.predict(X_test))
# Out:
# 4/4 [==============================] - 3s 41ms/step
# 6/6 [==============================] - 3s 52ms/step

# %%
import math
from sklearn.metrics import mean_squared_error

math.sqrt(mean_squared_error(y_train,train_preds))
# Out:
# 125.76420238641218

# %%
# Plot of Predictions on Closing Price made by our model on training dataset vs Actual Closing Price

plt.plot(minmax.inverse_transform(close_df))
plt.plot(train_preds)
plt.title("Variation of Predicted trained dataset(orange) and actual dataset(lightblue)", color="orange", fontsize=16, fontweight="bold")
plt.xlabel("Data Index Number")
plt.ylabel("Clossing price");

# %%
# Plot of Predictions on Closing Price made by our model on training dataset vs Actual Closing Price
# vs Predictions on CLosing Price made by our model on test dataset

plt.plot(minmax.inverse_transform(close_df))
plt.plot(train_preds)
plt.title("Variation of Predicted tested dataset(green) and actual dataset(lightblue)", color="orange", fontsize=16, fontweight="bold")
plt.xlabel("Data Index Number")
plt.ylabel("Clossing price");
plt.plot(test_preds)
plt.show()
